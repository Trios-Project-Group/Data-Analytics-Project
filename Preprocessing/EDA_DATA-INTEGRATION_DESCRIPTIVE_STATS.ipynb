# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy import stats
warnings.filterwarnings('ignore')

# %% [markdown]
# # Performing EDA and getting to know the data better

# %% [markdown]
# <b>Loading the data and determining its shape</b>

# %%
dataframe = pd.read_csv('../Dataset/Development.csv')

# %%
dataframe.columns
# Out:
# Index(['id', 'title', 'url', 'is_paid', 'num_subscribers', 'avg_rating',
#        'avg_rating_recent', 'rating', 'num_reviews', 'num_published_lectures',
#        'num_published_practice_tests', 'created', 'published_time',
#        'discount_price__amount', 'discount_price__currency',
#        'price_detail__amount', 'price_detail__currency'],
#       dtype='object')

# %%
dataframe.shape
# Out:
# (9932, 17)

# %%
dataframe.head(4)
# Out:
#        id                                              title  \
# 0  567828  2020 Complete Python Bootcamp: From Zero to He...
# 1  625204                         The Web Developer Bootcamp
# 2  950390  Machine Learning A-Z™: Hands-On Python & R In ...
# 3  756150        Angular - The Complete Guide (2020 Edition)
#
#                                         url  is_paid  num_subscribers  \
# 0         /course/complete-python-bootcamp/     True          1086954
# 1       /course/the-web-developer-bootcamp/     True           592474
# 2                  /course/machinelearning/     True           687330
# 3  /course/the-complete-guide-to-angular-2/     True           417746
#
#    avg_rating  avg_rating_recent   rating  num_reviews  \
# 0     4.56326            4.56743  4.56743       314098
# 1     4.64777            4.65291  4.65291       181621
# 2     4.55210            4.54932  4.54932       131007
# 3     4.57687            4.58594  4.58594       128705
#
#    num_published_lectures  num_published_practice_tests               created  \
# 0                     152                             0  2015-07-29T00:12:23Z
# 1                     405                             0  2015-09-28T21:32:19Z
# 2                     323                             0  2016-09-05T09:54:22Z
# 3                     455                             0  2016-02-08T17:02:55Z
#
#          published_time  discount_price__amount discount_price__currency  \
# 0  2015-10-12T21:42:53Z                   455.0                      INR
# 1  2015-11-02T21:13:27Z                   455.0                      INR
# 2  2016-09-13T21:43:44Z                   455.0                      INR
# 3  2016-02-11T07:29:29Z                   462.0                      INR
#
#    price_detail__amount price_detail__currency
# 0                  8640                    INR
# 1                  8640                    INR
# 2                  8640                    INR
# 3                  8640                    INR

# %% [markdown]
# <b>examining unwanted features/attributes in a table </b>

# %%
dataframe['discount_price__currency'].value_counts()
# Out:
# INR    9764
# Name: discount_price__currency, dtype: int64

# %% [markdown]
# <b>Since The Currency is recorded in the format INR for every instance , we drop the currency spec columns from the dataframe and Rename the Data Columns by specifying the currency units. <b>

# %%
dataframe.drop(['price_detail__currency','discount_price__currency'],axis = 'columns',inplace = True)

# %% [markdown]
# <b>In the below cell ,we capture the missing values in a column 'price_detail__currency' , which implies that few samples have this feature mising </b>

# %% [markdown]
# shape of dataframe after eliminating 2 dimensions (attributes)

# %%
dataframe.shape
# Out:
# (9932, 15)

# %%
dataframe.dtypes
# Out:
# id                                int64
# title                            object
# url                              object
# is_paid                            bool
# num_subscribers                   int64
# avg_rating                      float64
# avg_rating_recent               float64
# rating                          float64
# num_reviews                       int64
# num_published_lectures            int64
# num_published_practice_tests      int64
# created                          object
# published_time                   object
# discount_price__amount          float64
# price_detail__amount              int64
# dtype: object

# %% [markdown]
# <b>YEAR-WISE COURSES OFFERED BY UDEMY</b>
#
# * to find the no.of.courses offered every year in Udemy , we perform some preprocessing
# * extract the year from the date attribut

# %%
def extract_year(record):
    
    return pd.to_datetime(record,format='%Y-%m-%d').year

dataframe['year_created']=dataframe['created'].apply(extract_year)

dataframe['year_created'].head()
# Out:
# 0    2015
# 1    2015
# 2    2016
# 3    2016
# 4    2015
# Name: year_created, dtype: int64

# %%
plt.figure(figsize=(8,7))
sns.set(style='whitegrid', palette="deep", font_scale=1.1)
plot = sns.countplot(dataframe['year_created'])
plot.set_ylabel('courses created')
plot.set_title('Courses Offered By Udemy From 2011 - 2020')
# Out:
# Text(0.5, 1.0, 'Courses Offered By Udemy From 2011 - 2020')

# %% [markdown]
# # Impact created by pandemic in 2020 on the courses offered by Udemy
#
# * We'll perform a drill down operation and look into the courses offered per month for the year 2020 .

# %%
def extract_month(record):
    
    return pd.to_datetime(record,format='%Y-%m-%d').month

courses_per_month_2020 = dataframe[dataframe['year_created']==2020]

courses_per_month_2020['month_created'] = courses_per_month_2020['created'].apply(extract_month)

# %%
plt.figure(figsize=(8,8))
sns.set(style='whitegrid', palette="deep", font_scale=1.1)
plot2=sns.countplot(courses_per_month_2020['month_created'])
plot2.set_ylabel('Courses_Per_month')
plot2.set_title('Courses offered in the Year 2020 : A drill down Operation')
# Out:
# Text(0.5, 1.0, 'Courses offered in the Year 2020 : A drill down Operation')

# %% [markdown]
# <b>Key observation :
#
#         *Notice that the no.of.courses created in the month of April reflects a spike
#         *Since the data is hierarchical , a drill down operation was possible
# </b>

# %% [markdown]
# <b>How many paid courses veruse non-paid courses</b>

# %%
dataframe['is_paid'].value_counts()
# Out:
# True    9932
# Name: is_paid, dtype: int64

# %% [markdown]
# # correlation between the features of the course statistics

# %%
plt.figure(figsize=(10,10))

to_correlate = dataframe[['num_subscribers','num_reviews']]

plt.subplot(2, 1, 1)
sns.heatmap(to_correlate.corr(),annot=True)

# %% [markdown]
# <b> The observation is that num_reviews received  by a course and the total no.of.subscribers for a course are highly correlated!! </b>

# %% [markdown]
# Correlation between all numerical parameters in the dataframe is seen below

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dataframe.drop('is_paid',axis=1).corr(),annot=True,fmt = '.2g' ,linecolor='white',linewidths=2,cmap='Spectral')

# %% [markdown]
# <b>The above plot shows correlation between all the paremeters/attributes.Typically num_reviews is highly correlated with the num_subscribers for that course. </b>

# %%
sns.boxplot(dataframe['price_detail__amount'])

# %% [markdown]
# <b> Visualizing the distribution of a feature variable viz 'num_published_lectures' </b>

# %%
plt.figure(figsize=(12,8))
sns.set(style='whitegrid', palette="deep", font_scale=1.1)
sns.distplot(dataframe['num_published_lectures'],bins=20)
plt.axvline(np.mean(dataframe['num_published_lectures']),color='b', linestyle=':')
mode = stats.mode(dataframe['num_published_lectures'])
plt.axvline(np.median(dataframe['num_published_lectures']),color='r', linestyle='--')
plt.axvline(mode[0],color='g', linestyle='-')
plt.legend({'Mean':dataframe['num_published_lectures'].mean(),'Median':dataframe['num_published_lectures'].median(),'Mode':mode[0]})
plt.text(700,0.010,"Kurtosis : 17.079")
plt.text(700,0.008,"Skewness : 3.500")
# Out:
# Text(700, 0.008, 'Skewness : 3.500')

# %% [markdown]
# <b>From the above distribution we can see that the num_published_lectures is a right skewed distribution!
# Mode < Median < Mean </b>

# %% [markdown]
# <b>WHat were the most subscribed courses in every year from 2011-2020</b>

# %%
max_subs_per_year = dataframe.groupby('year_created')['num_subscribers'].transform(max) == dataframe['num_subscribers']

# %%
dataframe[max_subs_per_year][['title','num_subscribers','year_created']].sort_values('year_created')
# Out:
#                                                  title  num_subscribers  \
# 328                Become a Web Developer from Scratch            70926
# 240   The Complete 2020 Fullstack Web Developer Course            81732
# 73                Learn HTML5 Programming From Scratch           317673
# 9                  Complete C# Unity Game Developer 2D           362891
# 0    2020 Complete Python Bootcamp: From Zero to He...          1086954
# 2    Machine Learning A-Z™: Hands-On Python & R In ...           687330
# 126     The Complete Front-End Web Development Course!           308895
# 10   The Data Science Course 2020: Complete Data Sc...           320039
# 159    Java Programming: Complete Beginner to Advanced           233336
# 299  Python for beginners - Learn all the basics of...           106128
#
#      year_created
# 328          2011
# 240          2012
# 73           2013
# 9            2014
# 0            2015
# 2            2016
# 126          2017
# 10           2018
# 159          2019
# 299          2020

# %% [markdown]
# # Let's create a word cloud to visualize the most common courses and find out the most trending topics and buzzwords in IT_Development courses

# %%
from wordcloud import WordCloud,STOPWORDS

def title_wordcloud(titles):
    
    stop = set(STOPWORDS)
    
    additional_stopwords = ['Complete','Beginner','using','Advanced','create','step']
    
    for i in additional_stopwords:
        stop.add(i)
    
    
    
    wc = WordCloud(background_color='white',max_words=200).generate(titles)
    
    plt.figure(figsize=(10,10))
    
    plt.imshow(wc)
    
    

string_of_words = " "
titles_list = list(dataframe['title'].values)
string_of_words = string_of_words.join(titles_list)
title_wordcloud(string_of_words)

# %% [markdown]
# Data Inconsistencies

# %%
dataframe.describe()
# Out:
#                  id  num_subscribers   avg_rating  avg_rating_recent  \
# count  9.932000e+03     9.932000e+03  9932.000000        9932.000000
# mean   1.579035e+06     7.410613e+03     4.072721           4.055958
# std    8.361819e+05     2.589134e+04     0.496794           0.523469
# min    8.082000e+03     2.000000e+01     1.400000           1.337300
# 25%    9.287770e+05     3.750000e+02     3.800000           3.774955
# 50%    1.537401e+06     1.731000e+03     4.175220           4.166985
# 75%    2.242264e+06     5.739000e+03     4.437500           4.438873
# max    3.473846e+06     1.086954e+06     5.000000           5.000000
#
#             rating    num_reviews  num_published_lectures  \
# count  9932.000000    9932.000000             9932.000000
# mean      4.055958     687.041986               61.520842
# std       0.523469    5450.095041               71.216428
# min       1.337300       8.000000                0.000000
# 25%       3.774955      24.000000               22.000000
# 50%       4.166985      60.000000               39.000000
# 75%       4.438873     212.000000               72.000000
# max       5.000000  314098.000000              779.000000
#
#        num_published_practice_tests  discount_price__amount  \
# count                   9932.000000             9764.000000
# mean                       0.037857              466.730234
# std                        0.350750              146.976860
# min                        0.000000              455.000000
# 25%                        0.000000              455.000000
# 50%                        0.000000              455.000000
# 75%                        0.000000              455.000000
# max                        6.000000             3200.000000
#
#        price_detail__amount  year_created
# count           9932.000000   9932.000000
# mean            5254.321385   2017.303061
# std             3112.627009      1.815079
# min             1280.000000   2011.000000
# 25%             1600.000000   2016.000000
# 50%             6080.000000   2018.000000
# 75%             8640.000000   2019.000000
# max            12800.000000   2020.000000

# %% [markdown]
# <b>We can clearly see that for discount_price__amount column we have less numeric values than the original column length.
# Which Indicates we may have some inconsistency in the data , the data is missing </b>

# %% [markdown]
# <b>From Below we can infer that we have around 168 NaN values in the dataset column of discount_price__amount </b>

# %%
dataframe['discount_price__amount'].isnull().sum()
# Out:
# 168

# %% [markdown]
# <b>How To Fix this or How to clean this data
#
# We can see that the data objects having NaN value for discount_price_amount have a definite/consistent/non-null value for price_detail__amount. Hence we can possibly say that , such courses aren't available at a discounted_price .We can fill the missing values with their corresponding actual prices</b>

# %% [markdown]
# <b>Outlier Detection in price of the offered courses </b>
#
# Z-score approach to detect outliers
#
# if z score of the attribute for a  data object is >3 or < -3 , we mark them as outliers

# %%
z_scores = np.abs(stats.zscore(dataframe['price_detail__amount']))

# %%
outliers = z_scores[z_scores > 3]

# %%
outliers
# Out:
# array([], dtype=float64)

# %% [markdown]
# Empty list indicatses that we have no outliers in the price_detail__amount attribute

# %% [markdown]
# # Data Integration , merging of 2 tables by altering the schema in an appropriate fashion ##

# %% [markdown]
# Till now , we handled only the dataset concerning the Development courses . A similar dataset has been identified by us for the CS - IT courses offered by Udemy , we shall perform some minor EDA and then clean it and further proceed on to merging the tables.

# %%
dataframe2 = pd.read_csv('../Dataset/IT_Software.csv')

# %%
dataframe2.shape
# Out:
# (21317, 20)

# %%
dataframe2.columns
# Out:
# Index(['id', 'title', 'url', 'is_paid', 'num_subscribers', 'avg_rating',
#        'avg_rating_recent', 'rating', 'num_reviews', 'is_wishlisted',
#        'num_published_lectures', 'num_published_practice_tests', 'created',
#        'published_time', 'discount_price__amount', 'discount_price__currency',
#        'discount_price__price_string', 'price_detail__amount',
#        'price_detail__currency', 'price_detail__price_string'],
#       dtype='object')

# %%
dataframe.shape
# Out:
# (9932, 16)

# %%
dataframe.head()
# Out:
#        id                                              title  \
# 0  567828  2020 Complete Python Bootcamp: From Zero to He...
# 1  625204                         The Web Developer Bootcamp
# 2  950390  Machine Learning A-Z™: Hands-On Python & R In ...
# 3  756150        Angular - The Complete Guide (2020 Edition)
# 4  533682  Java Programming Masterclass for Software Deve...
#
#                                                 url  is_paid  num_subscribers  \
# 0                 /course/complete-python-bootcamp/     True          1086954
# 1               /course/the-web-developer-bootcamp/     True           592474
# 2                          /course/machinelearning/     True           687330
# 3          /course/the-complete-guide-to-angular-2/     True           417746
# 4  /course/java-the-complete-java-developer-course/     True           497195
#
#    avg_rating  avg_rating_recent   rating  num_reviews  \
# 0     4.56326            4.56743  4.56743       314098
# 1     4.64777            4.65291  4.65291       181621
# 2     4.55210            4.54932  4.54932       131007
# 3     4.57687            4.58594  4.58594       128705
# 4     4.56571            4.57203  4.57203       122306
#
#    num_published_lectures  num_published_practice_tests               created  \
# 0                     152                             0  2015-07-29T00:12:23Z
# 1                     405                             0  2015-09-28T21:32:19Z
# 2                     323                             0  2016-09-05T09:54:22Z
# 3                     455                             0  2016-02-08T17:02:55Z
# 4                     400                             0  2015-06-21T20:25:56Z
#
#          published_time  discount_price__amount  price_detail__amount  \
# 0  2015-10-12T21:42:53Z                   455.0                  8640
# 1  2015-11-02T21:13:27Z                   455.0                  8640
# 2  2016-09-13T21:43:44Z                   455.0                  8640
# 3  2016-02-11T07:29:29Z                   462.0                  8640
# 4  2015-07-21T22:01:13Z                   455.0                  8640
#
#    year_created
# 0          2015
# 1          2015
# 2          2016
# 3          2016
# 4          2015

# %%
dataframe2.head()
# Out:
#         id                                              title  \
# 0   762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1   937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2  1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3   648826         The Complete Financial Analyst Course 2020
# 4   637930  An Entire MBA in 1 Course:Award Winning Busine...
#
#                                                  url is_paid  num_subscribers  \
# 0                 /course/the-complete-sql-bootcamp/    True         295509.0
# 1                                 /course/tableau10/    True         209070.0
# 2                        /course/pmp-pmbok6-35-pdus/    True         155282.0
# 3     /course/the-complete-financial-analyst-course/    True         245860.0
# 4  /course/an-entire-mba-in-1-courseaward-winning...    True         374836.0
#
#    avg_rating  avg_rating_recent   rating  num_reviews is_wishlisted  \
# 0     4.66019            4.67874  4.67874      78006.0         False
# 1     4.58956            4.60015  4.60015      54581.0         False
# 2     4.59491            4.59326  4.59326      52653.0         False
# 3     4.54407            4.53772  4.53772      46447.0         False
# 4     4.47080            4.47173  4.47173      41630.0         False
#
#    num_published_lectures  num_published_practice_tests               created  \
# 0                    84.0                           0.0  2016-02-14T22:57:48Z
# 1                    78.0                           0.0  2016-08-22T12:10:18Z
# 2                   292.0                           2.0  2017-09-26T16:32:48Z
# 3                   338.0                           0.0  2015-10-23T13:34:35Z
# 4                    83.0                           0.0  2015-10-12T06:39:46Z
#
#          published_time  discount_price__amount discount_price__currency  \
# 0  2016-04-06T05:16:11Z                   455.0                      INR
# 1  2016-08-23T16:59:49Z                   455.0                      INR
# 2  2017-11-14T23:58:14Z                   455.0                      INR
# 3  2016-01-21T01:38:48Z                   455.0                      INR
# 4  2016-01-11T21:39:33Z                   455.0                      INR
#
#   discount_price__price_string  price_detail__amount price_detail__currency  \
# 0                         ₹455                8640.0                    INR
# 1                         ₹455                8640.0                    INR
# 2                         ₹455                8640.0                    INR
# 3                         ₹455                8640.0                    INR
# 4                         ₹455                8640.0                    INR
#
#   price_detail__price_string
# 0                     ₹8,640
# 1                     ₹8,640
# 2                     ₹8,640
# 3                     ₹8,640
# 4                     ₹8,640

# %%
dataframe2['discount_price__currency'].value_counts()
# Out:
# INR    19580
# Name: discount_price__currency, dtype: int64

# %%
21024+1829
# Out:
# 22853

# %%
dataframe2.drop(['price_detail__currency','discount_price__currency','price_detail__price_string','is_wishlisted'],axis = 'columns',inplace = True)

# %%
dataframe2.shape
# Out:
# (21317, 16)

# %%
dataframe2.drop('discount_price__price_string',axis = 'columns',inplace = True)

# %%
dataframe2['year_created']=dataframe2['created'].apply(extract_year)

# %%
dataframe2
# Out:
#             id                                              title  \
# 0       762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3       648826         The Complete Financial Analyst Course 2020
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...
# ...        ...                                                ...
# 21312  1577948                   Social Engineering Expert (Lite)
# 21313   205908  LastPass and Google Authenticator for Password...
# 21314  1292572                            Splunk 6.X Fundamentals
# 21315  2206118  CSSLP: Certified Secure Software Lifecycle Pro...
# 21316  1969416                   Ethical Hacking: Man in the Midd
#
#                                                      url is_paid  \
# 0                     /course/the-complete-sql-bootcamp/    True
# 1                                     /course/tableau10/    True
# 2                            /course/pmp-pmbok6-35-pdus/    True
# 3         /course/the-complete-financial-analyst-course/    True
# 4      /course/an-entire-mba-in-1-courseaward-winning...    True
# ...                                                  ...     ...
# 21312            /course/social-engineering-expert-lite/    True
# 21313                                  /course/lastpass/    True
# 21314                    /course/splunk-6x-fundamentals/    True
# 21315  /course/csslp-certified-secure-software-lifecy...    True
# 21316                                                NaN     NaN
#
#        num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 0             295509.0     4.66019            4.67874  4.67874      78006.0
# 1             209070.0     4.58956            4.60015  4.60015      54581.0
# 2             155282.0     4.59491            4.59326  4.59326      52653.0
# 3             245860.0     4.54407            4.53772  4.53772      46447.0
# 4             374836.0     4.47080            4.47173  4.47173      41630.0
# ...                ...         ...                ...      ...          ...
# 21312             42.0     4.21429            4.13557  4.13557          7.0
# 21313            503.0     4.14286            4.07559  4.07559          7.0
# 21314             28.0     3.92857            3.88253  3.88253          7.0
# 21315             56.0     1.64286            1.46335  1.46335          7.0
# 21316              NaN         NaN                NaN      NaN          NaN
#
#        num_published_lectures  num_published_practice_tests  \
# 0                        84.0                           0.0
# 1                        78.0                           0.0
# 2                       292.0                           2.0
# 3                       338.0                           0.0
# 4                        83.0                           0.0
# ...                       ...                           ...
# 21312                     9.0                           0.0
# 21313                    20.0                           0.0
# 21314                    15.0                           0.0
# 21315                     0.0                           5.0
# 21316                     NaN                           NaN
#
#                     created        published_time  discount_price__amount  \
# 0      2016-02-14T22:57:48Z  2016-04-06T05:16:11Z                   455.0
# 1      2016-08-22T12:10:18Z  2016-08-23T16:59:49Z                   455.0
# 2      2017-09-26T16:32:48Z  2017-11-14T23:58:14Z                   455.0
# 3      2015-10-23T13:34:35Z  2016-01-21T01:38:48Z                   455.0
# 4      2015-10-12T06:39:46Z  2016-01-11T21:39:33Z                   455.0
# ...                     ...                   ...                     ...
# 21312  2018-03-02T17:41:29Z  2018-03-02T23:41:26Z                   455.0
# 21313  2014-04-27T11:53:54Z  2014-04-30T10:20:50Z                   455.0
# 21314  2017-07-14T20:01:48Z  2017-08-03T21:55:29Z                     NaN
# 21315  2019-02-08T12:14:23Z  2019-02-08T12:51:36Z                   455.0
# 21316                   NaN                   NaN                     NaN
#
#        price_detail__amount  year_created
# 0                    8640.0        2016.0
# 1                    8640.0        2016.0
# 2                    8640.0        2017.0
# 3                    8640.0        2015.0
# 4                    8640.0        2015.0
# ...                     ...           ...
# 21312                1280.0        2018.0
# 21313                4800.0        2014.0
# 21314                1280.0        2017.0
# 21315                2240.0        2019.0
# 21316                   NaN           NaN
#
# [21317 rows x 16 columns]

# %%
common_courses = set(dataframe['id'].values) & set(dataframe2['id'].values)

# %%
dataframe.shape
# Out:
# (9932, 16)

# %%
common_id = set(dataframe['id'].values) & set(dataframe2['id'].values)

# %%
indices =[]

for x in common_id:
    b=dataframe[dataframe['id'] == x].index
    indices.append(b[0])

# %%
dataframe.shape
# Out:
# (9932, 16)

# %%
indices[0]
# Out:
# 8583

# %%
dataframe_after_drop=dataframe.drop(dataframe.index[indices],axis =0,)

# %%
dataframe.shape
# Out:
# (9932, 16)

# %%
dataframe_after_drop.shape
# Out:
# (9898, 16)

# %%
set(dataframe_after_drop['id'].values) & set(dataframe2['id'].values)
# Out:
# set()

# %%
Merged_data = pd.concat([dataframe_after_drop,dataframe2],ignore_index=True)

# %%
Merged_data.reset_index()
# Out:
#        index       id                                              title  \
# 0          0   567828  2020 Complete Python Bootcamp: From Zero to He...
# 1          1   625204                         The Web Developer Bootcamp
# 2          2   950390  Machine Learning A-Z™: Hands-On Python & R In ...
# 3          3   756150        Angular - The Complete Guide (2020 Edition)
# 4          4   533682  Java Programming Masterclass for Software Deve...
# ...      ...      ...                                                ...
# 31210  31210  1577948                   Social Engineering Expert (Lite)
# 31211  31211   205908  LastPass and Google Authenticator for Password...
# 31212  31212  1292572                            Splunk 6.X Fundamentals
# 31213  31213  2206118  CSSLP: Certified Secure Software Lifecycle Pro...
# 31214  31214  1969416                   Ethical Hacking: Man in the Midd
#
#                                                      url is_paid  \
# 0                      /course/complete-python-bootcamp/    True
# 1                    /course/the-web-developer-bootcamp/    True
# 2                               /course/machinelearning/    True
# 3               /course/the-complete-guide-to-angular-2/    True
# 4       /course/java-the-complete-java-developer-course/    True
# ...                                                  ...     ...
# 31210            /course/social-engineering-expert-lite/    True
# 31211                                  /course/lastpass/    True
# 31212                    /course/splunk-6x-fundamentals/    True
# 31213  /course/csslp-certified-secure-software-lifecy...    True
# 31214                                                NaN     NaN
#
#        num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 0            1086954.0     4.56326            4.56743  4.56743     314098.0
# 1             592474.0     4.64777            4.65291  4.65291     181621.0
# 2             687330.0     4.55210            4.54932  4.54932     131007.0
# 3             417746.0     4.57687            4.58594  4.58594     128705.0
# 4             497195.0     4.56571            4.57203  4.57203     122306.0
# ...                ...         ...                ...      ...          ...
# 31210             42.0     4.21429            4.13557  4.13557          7.0
# 31211            503.0     4.14286            4.07559  4.07559          7.0
# 31212             28.0     3.92857            3.88253  3.88253          7.0
# 31213             56.0     1.64286            1.46335  1.46335          7.0
# 31214              NaN         NaN                NaN      NaN          NaN
#
#        num_published_lectures  num_published_practice_tests  \
# 0                       152.0                           0.0
# 1                       405.0                           0.0
# 2                       323.0                           0.0
# 3                       455.0                           0.0
# 4                       400.0                           0.0
# ...                       ...                           ...
# 31210                     9.0                           0.0
# 31211                    20.0                           0.0
# 31212                    15.0                           0.0
# 31213                     0.0                           5.0
# 31214                     NaN                           NaN
#
#                     created        published_time  discount_price__amount  \
# 0      2015-07-29T00:12:23Z  2015-10-12T21:42:53Z                   455.0
# 1      2015-09-28T21:32:19Z  2015-11-02T21:13:27Z                   455.0
# 2      2016-09-05T09:54:22Z  2016-09-13T21:43:44Z                   455.0
# 3      2016-02-08T17:02:55Z  2016-02-11T07:29:29Z                   462.0
# 4      2015-06-21T20:25:56Z  2015-07-21T22:01:13Z                   455.0
# ...                     ...                   ...                     ...
# 31210  2018-03-02T17:41:29Z  2018-03-02T23:41:26Z                   455.0
# 31211  2014-04-27T11:53:54Z  2014-04-30T10:20:50Z                   455.0
# 31212  2017-07-14T20:01:48Z  2017-08-03T21:55:29Z                     NaN
# 31213  2019-02-08T12:14:23Z  2019-02-08T12:51:36Z                   455.0
# 31214                   NaN                   NaN                     NaN
#
#        price_detail__amount  year_created
# 0                    8640.0        2015.0
# 1                    8640.0        2015.0
# 2                    8640.0        2016.0
# 3                    8640.0        2016.0
# 4                    8640.0        2015.0
# ...                     ...           ...
# 31210                1280.0        2018.0
# 31211                4800.0        2014.0
# 31212                1280.0        2017.0
# 31213                2240.0        2019.0
# 31214                   NaN           NaN
#
# [31215 rows x 17 columns]

# %%
#Merged_data.to_csv('Integrated_CS_IT_DEV.csv')
